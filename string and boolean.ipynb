# %%
#concatination of two strings
a="kartik"
b="kumar"
c=a+b
print(c)
# Out:
# kartikkumar

# %%
#concatination of two strings
a="kartik"
b="kumar"
c=a+" "+b
print(c)
# Out:
# kartik kumar

# %%
#it will give error because we are trying to concatinate string with integer
age = 21
name = "kartik"+age
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 age = 21
# ----> 2 name = "kartik"+age
#       3 print(name)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 21
name = "kartik"+" "+str(age)
print(name)
# Out:
# kartik 21

# %%
#F-string 
age = 21
name = f"kartik {age}and i am learning python in {25} days"
print(name)
# Out:
# kartik 21and i am learning python in 25 days

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
#this is something unique to python
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
name="Kartik"
print(name.capitalize())
print(name.upper())
print(name.lower())
print(name.title())
print(name.strip())
print(name.casefold())
print(name.center(20))
# Out:
# Kartik
# KARTIK
# kartik
# Kartik
# Kartik
# kartik
#        Kartik

# %%
# Boolean Methods
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")  
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = "hello"
y = 15
c=0
print(bool(c))
print(bool(x))
print(bool(y))
# Out:
# False
# True
# True
