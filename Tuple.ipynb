# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
k=tuple('apple')
print(k)  # Output: ('a', 'p', 'p', 'l', 'e')
# Out:
# ('a', 'p', 'p', 'l', 'e')

# %%
k=("apple","banana","cherry ")
print(k)  # Output: ('apple', 'banana', 'cherry ')
# Out:
# ('apple', 'banana', 'cherry ')

# %%
k=("apple","banana","cherry ")
print(len(k))
# Out:
# 3

# %%
k=("kartik")
print(len(k))
print(k)
# Out:
# 6
# kartik

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1]) # sane as list indexing
# Out:
# banana

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1]) # same as list indexing
# Out:
# cherry

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5]) #slicing same as list
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[-4:-1]) #slicing same as list using negative indexing
# Out:
# ('orange', 'kiwi', 'melon')

# %%
thistuple = ("apple", "banana", "cherry")
if "apple" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %%
k=("apple", "banana", "cherry",1,2.5,True)
for x in k:
  print(x)
  print(type(x))
  print(type(k))
# Out:
# apple
# <class 'str'>
# <class 'tuple'>
# banana
# <class 'str'>
# <class 'tuple'>
# cherry
# <class 'str'>
# <class 'tuple'>
# 1
# <class 'int'>
# <class 'tuple'>
# 2.5
# <class 'float'>
# <class 'tuple'>
# True
# <class 'bool'>
# <class 'tuple'>

# %%
# Modifying a tuple by converting it to a list and back to a tuple
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
# appending an item to a tuple
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)

# %%
# adding items to a tuple by concatenation
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %% [markdown]
# #  Removing items

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 thistuple = ("apple", "banana", "cherry")
#       2 del thistuple
# ----> 3 print(thistuple)
#
# NameError: name 'thistuple' is not defined

# %% [markdown]
# # Unpack

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry
# apple
# banana
# cherry

# %% [markdown]
# # Loop

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry
