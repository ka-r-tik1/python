# %% [markdown]
# # OPerators

# %%
p = 50 + 100
print(p)
print(type(p))
sum = 5 + 1.5
print(sum)
sum2 = p + sum
print(sum2)
sum3 = sum + sum2
print(sum3)
# Out:
# 150
# <class 'int'>
# 6.5
# 156.5
# 163.0

# %%
x = 12
y = 5
z= 15%4
print(z)

print(x / y)
# Out:
# 3
# 2.4

# %%
a=5
a += 12
print(a)
# Out:
# 17

# %%
numbers = [1, 2, 3, 4, 5]
count = len(numbers)
if count > 3:
    print(f"List has {count} elements")

if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements
# List has 5 elements

# %%
numbers = [1, 2, 3, 4, 5]
count = len(numbers)
print(count)
# Out:
# 5

# %%
if count > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements

# %%
#walrus operator version
if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements

# %% [markdown]
# # Comparision

# %%
x = 5
y = 3

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x = 5

print(1 < x < 10)

print(1 < x and x < 10)
# Out:
# True
# True

# %% [markdown]
# # Logical OP

# %%
x = 5

print(1 < x < 10)

print(1 < x and x < 10)

print(x < 5 or x > 10)
# Out:
# True
# True
# False

# %%
# is for memory location comparison (== for value comparison)
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
x = [1, 2, 3]
y = [1, 2, 3]


print(x == y)
print(x is y)
# Out:
# True
# False

# %% [markdown]
# # Membership Op

# %%
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)

fruits = ["apple", "banana", "cherry"]

print("pineapple" not in fruits)

text = "Hello World"

print("H" in text)
print("hello" in text)
print("z" not in text)
# Out:
# True
# True
# True
# False
# True
