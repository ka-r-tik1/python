# %%
#exercise to check if a variable is float or not 
x = float(5)

if type(x) == float:
    print("x is float")
else:
    print("x is not float")
# Out:
# x is float

# %%
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
#STRING are ARRAYS OF CHARACTERS
a = "Hello, World!"
print(a[1])  #prints e
print(a[7])  #prints W
print(a[1:5])  #prints ello
# Out:
# e
# W
# ello

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %% [markdown]
# #DATA TYPE

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = 20.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = "fantastic"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x= True
print(type(x))
# Out:
# <class 'bool'>

# %%
x = ["apple", "banana", "cherry"]
print(type(x))
# Out:
# <class 'list'>

# %%
x = {"name" : "John", "age" : 36}
print(type(x))
# Out:
# <class 'dict'>

# %%
x = {"name" , "John", "age"}
print(type(x))
# Out:
# <class 'set'>

# %%
x= ("apple", "banana", "cherry")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = frozenset(("apple", "banana", "cherry"))
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = frozenset({"apple", "banana", "cherry"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = (1, 5, 3)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = 1
y = 35656222554887711
z = -3255522

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 35e3
y = 12E4
z = -87.7e100

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = 3+5j
y = 5j
z = -5j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# #python modify strings

# %%
#python modify strings
a = "Hello, World!"
print(a.upper())
print(a.lower())
print(a.replace("H", "J"))
print(a.split(","))  #returns ['Hello', ' World!']
print(a.strip())  #removes any whitespace from the beginning or the end
# Out:
# HELLO, WORLD!
# hello, world!
# Jello, World!
# ['Hello', ' World!']
# Hello, World!

# %%
# Out:
# Hello, World!
