# %%
kartik={"apple","banana","cherry"}
print(kartik)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}
print(set1)
print(set2)
print(set3)
# Out:
# {'cherry', 'apple', 'banana'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
set1 = {"abc", 34, True, 40, "male"}
print(set1)
# Out:
# {True, 34, 'male', 'abc', 40}

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %%
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
k=list(thisset)
print(type(k))
# Out:
# <class 'list'>

# %%
k={"apple","banana","cherry"}
for x in k:
    print(x)
# Out:
# cherry
# apple
# banana

# %%
k={"apple","banana","cherry"}
print("banana" in k)
# Out:
# True

# %%
kartik={"apple","banana","cherry"}
print("kartik"not in kartik)
# Out:
# True

# %% [markdown]
# # Add items

# %%
kartik={"apple","banana","cherry"}
kartik.add("orange")
print(kartik)
# Out:
# {'cherry', 'apple', 'orange', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'papaya', 'mango', 'pineapple', 'banana', 'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'orange', 'apple', 'banana', 'kiwi', 'cherry'}

# %% [markdown]
# # Remove

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.discard("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x)

print(thisset)
# Out:
# cherry
# {'apple', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
thisset = {"apple", "banana", "cherry"}

del thisset

print(thisset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 thisset = {"apple", "banana", "cherry"}
#       3 del thisset
# ----> 5 print(thisset)
#
# NameError: name 'thisset' is not defined

# %% [markdown]
# # Loop

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# apple
# banana

# %% [markdown]
# # union
# union methods returns a new set with all items from both sets

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)# union methods returns a new set with all items from both sets
print(set3)
# Out:
# {1, 'a', 2, 3, 'b', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
print(set3)
# Out:
# {1, 'a', 2, 3, 'b', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set2.union(set1, set3, set4)
print(myset)
# Out:
# {1, 2, 3, 'a', 'John', 'b', 'apple', 'Elena', 'c', 'bananas', 'cherry'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1 | set2 | set3 |set4
print(myset)
# Out:
# {1, 'a', 2, 3, 'John', 'b', 'apple', 'Elena', 'c', 'bananas', 'cherry'}

# %%
x = {"a", "b", "c"}
y = (1, 2, 3)

z = x.union(y)
print(z)
# Out:
# {1, 'a', 2, 3, 'b', 'c'}

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {1, 'a', 2, 3, 'b', 'c'}

# %% [markdown]
# # intersection
# method will return a new set  that only contains the items that are present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %% [markdown]
# # update

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}

set3 = set1.intersection(set2)

print(set3)
# Out:
# {False, 1, 'apple'}

# %% [markdown]
# # diffrence

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2
print(set3)
# Out:
# {'banana', 'cherry'}

# %% [markdown]
# # diffrence update

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)
# Out:
# {'banana', 'google', 'microsoft', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3) # it will print items that are in either set1 or set2 but not in both
# Out:
# {'banana', 'google', 'microsoft', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)  # it will print items that are in either set1 or set2 but not in both
# Out:
# {'banana', 'google', 'microsoft', 'cherry'}

# %% [markdown]
# # frozenset

# %% [markdown]
# # frozenset cant add, remove ,discard , pop and clear

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
x.discard("banana")
print(x)
# Out:
# frozenset({'cherry', 'apple', 'banana'})
# <class 'frozenset'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 4
#       2 print(x)
#       3 print(type(x))
# ----> 4 x.discard("banana")
#       5 print(x)
#
# AttributeError: 'frozenset' object has no attribute 'discard'

# %%
x = {"apple", "banana", "cherry"}
x.discard("banana")
print(x)
# Out:
# {'cherry', 'apple'}
