# %%
print("hello ,kartik!")
# Out:
# hello ,kartik!

# %%
import sys
print(sys.version)
# Out:
# 3.11.11 | packaged by conda-forge | (main, Mar  3 2025, 20:29:43) [MSC v.1943 64 bit (AMD64)]

# %%
if 5 > 2:
    print("5 is greater than 2")
# Out:
# 5 is greater than 2

# %%
if 5 > 2:
 print("Five is greater than two!") 
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
#python Variables a
x = 5
y = "Hello, World!"
print(x)
# Out:
# 5

# %%
print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %%
print("Python is fun!") print("Really!")
# Out:
#   Cell In[18], line 1
#     print("Python is fun!") print("Really!")
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# end function

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print ("Hello World!", end="***")
print("I will print on the same line.")
# Out:
# Hello World!***I will print on the same line.

# %%
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
print(3+3)
print(7-4)
# Out:
# 6
# 3

# %% [markdown]
# 1 st logic

# %%
if 5 > 2:
    print("Hello World!", end="***")
# Out:
# Hello World!***

# %%
print("i am kartik",26,"years old", sep="---")
# Out:
# i am kartik---26---years old

# %%
x=str(3.5)    # x will be '3'
y=int(3)    # y will be 3
z=float(3)  # z will be 3.0
print(x)
# Out:
# 3.5

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 4
A = "Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
#camel case 
myVariableName = "John"
#pascal case
MyVariableName = "John"
#snake case
my_variable_name = "John"
print(myVariableName)
# Out:
# John

# %%
#multiple variables
x, y, z = "Orange", "Banana", "Cherry"
print(x)
# Out:
# Orange

# %%
#one value to multiple variables
x = y = z = "Orange"
print(y)
print(z)
# Out:
# Orange
# Orange

# %%
#unpacking a collection list,tuple,set python allow unpacking
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %%
x = 5
y = "John"
print(x, y, sep=" ")
# Out:
# 5 John

# %%
print("Hello"," World!")
# Out:
# Hello  World!

# %%
#Global Variables
x = "awesome"
def myfunc():
  print("Python is " + x)
myfunc()
#a= 'kartik '+x
#print(a,end=" ")
#print("is great.")
# Out:
# Python is awesome

# %%
#Global Variables
x = "awesome"
def myfunc():
  return
  #print("Python is " + x)
a= 'kartik '+x
print(a,end=" ")
print("is great.")
# Out:
# kartik awesome is great.

# %%
#Global Variables

def myfunc():
    print("Python is " )
  
print(myfunc())
# Out:
# Python is
# None

# %%
#Create a variable inside a function, with the same name as the global variable
x = "fantastic"
def myfunc():
    x = "awesome"
    print("Python is " + x)
myfunc()

print('python'+x)
# Out:
# Python is awesome
# pythonfantastic

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
#Declare a global variable inside a function, and use it outside the function:
#create a function:
def myfunction():
  global x
  x = "hello"

#execute the function:
myfunction()

#x should now be global, and accessible in the global scope.
print(x)
# Out:
# hello

# %%
def myfunc():
    global x
    x = "fantastic"

    print(x)
myfunc()
# Out:
# fantastic

# %%
#create a function:
def myfunction():
  global x
  x = "hello"

#execute the function:
myfunction()

#x should now be global, and accessible in the global scope.
print(x)
# Out:
# hello
