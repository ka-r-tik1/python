# %%
x = 'awesome'
def myfunc():
  global x
  x = 'fantastic'
myfunc()
print('Python is ' + x)
# Out:
# Python is fantastic

# %%
A = 10
def myfunc():
    global A
    A = 15
    if A > 5:
        print("A is greater than 5")
    else:
         print("A is less than or equal to 5")
myfunc()
# Out:
# A is greater than 5

# %%
A=B=C=20
def myfunc():
    global A,B,C
    A=5
    B=10
    C=15
    #print(A,B,C)
myfunc()
print(A,B,C,sep=" , ")
# Out:
# 5 , 10 , 15
