# %%
c = "kartik"
def greet():
    print("Hello, " + c + "! Welcome aboard.")
greet()
# Out:
# Hello, kartik! Welcome aboard.

# %%
x = 'awesome'
def myfunc():
  global x
  x = 'fantastic'
myfunc()
print('Python is ' + x)
# Out:
# Python is fantastic

# %%
#def and if else
A = 10
def myfunc():
    global A
    A = 15
    if A > 5:
        print("A is greater than 5")
    else:
         print("A is less than or equal to 5")
myfunc()
# Out:
# A is greater than 5

# %%
#multiple global variables can be declared in a function and changed
A=B=C=20
def myfunc():
    global A,B,C
    A=5
    B=10
    C=15
    #print(A,B,C)
myfunc()
print(A,B,C,sep=" , ")
# Out:
# 5 , 10 , 15

# %%
# Check if x is float or not
x = float(5)

if type(x) == float:
    print("x is float")
else:
    print("x is not float")

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
#STRING check
a = "Hello, World!"
if 'Hello' in a:
    print("Yes, 'ur word' is present.")
else:
    print("No, 'ur word' is NOT present.")
# Out:
# Yes, 'ur word' is present.

# %%
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %%
#slicing string
b="Hello, World!"
print(b[0])
# Out:
# H

# %%
#slicing string
b="kartik"
print(b[-1])
# Out:
# k

# %%
#string slicing
b="Hello,World!"
print(b[2:10])
# Out:
# llo,Worl

# %%
#slicing from the start 
b="Hello,World!"
print(b[:10])
# Out:
# Hello,Worl

# %%
a="kartik"
print(a[2:])
# Out:
# rtik

# %%
b="Hello,World"
print(b[-5:-2])
# Out:
# Wor

# %%
b="Hello,World!"
print(b[1:5])
# Out:
# ello

# %%
k="k a"
print(k[-2])

# %%
#if 
#def 
#list slicing

# %% [markdown]
# #Boolean funtion

# %%
class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
class MyClass:
    def __len__(self):
       return 3

obj = MyClass()

if obj:
    print("True")
else:
    print("False")
# Out:
# True

# %%
class MyClass:
    def __len__(self):
       return 0

obj = MyClass()

if obj:
    print("True")
else:
    print("False")
# Out:
# False

# %%
def myFunction() :
  return True
myFunction()
#print(myFunction())
# Out:
# True

# %%
def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# YES!

# %%
def myFunction() :
  return 

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# NO!

# %%
x = 200
print(isinstance(x, int))
# Out:
# True
