# %% [markdown]
# # sort list

# %%
kartik=["apple","banana","cherry","e","d"]
kartik.sort()
print(kartik)
# Out:
# ['apple', 'banana', 'cherry', 'd', 'e']

# %%
k=[10,50,20,40,30]
k.sort()
print(k)
# Out:
# [10, 20, 30, 40, 50]

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)# it will sort based on the value returned by myfunc
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %% [markdown]
# # Copy method

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
#mylist = thislist # example it create same key for same house
mylist = thislist.copy() # it create different house 
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]# slice operator
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# # join list

# %%
k=["kartik","is","a","good","boy"]
v=[1,2,3,4,5]
#z=zip(k,v)# it will create tuples of both list
#print(list(z))
z=k+v
print(z)
# Out:
# ['kartik', 'is', 'a', 'good', 'boy', 1, 2, 3, 4, 5]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
